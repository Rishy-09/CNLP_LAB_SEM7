# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishy-09/CNLP_LAB_SEM7/blob/main/Notebooks/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 2: Basic Text Preprocessing
#
# ## Experiment 2.1: Basic Text Preprocessing
# Write a Python program to perform basic text preprocessing on a given data. The program should:
# 1. Convert text to lowercase. (Also display how many uppercase characters were converted)
# 2. Remove punctuation. (Also display how many different types of punctuations were removed)
# 3. Remove numbers. (Also display how many numbers were removed)
# 4. Remove extra whitespace. (Also display how much extra whitespace was present)
# 5. Display the cleaned text.

# %% [markdown]
# ### Experiment 2.1 Implementation

# %%
# Step 1: Read the content from the file
import os

file_name = '2.1_text_data.txt'

with open(file_name, 'r') as f:
    original_text = f.read()

print("Original Text:")
print(original_text)
print("\n" + "="*50 + "\n")
# Out:
# Original Text:
# Natural Language Processing (NLP) is a branch of Artificial Intelligence.  It helps computers understand and process human language.
#
# In 2026, NLP is used in many applications such as chatbots, machine translation, sentiment analysis, and text summarization!!!
#
# Text preprocessing is an important step in NLP.   It includes several operations such as cleaning text, removing punctuation, and removing unnecessary numbers.
#
# For example, a chatbot may process 1000+ customer messages every day. These messages can contain CAPITAL letters, numbers like 12345, punctuation marks!!!, and   extra spaces.
#
# The main goal of text preprocessing is to convert raw text into a clean and consistent format. This makes the text easier to analyze and use for further Natural Language Processing tasks.
#
# ...

# %%
# Step 2: Convert text to lowercase and count uppercase characters

uppercase_count = sum(1 for char in original_text if char.isupper())
text_lower = original_text.lower()

print(f"Number of uppercase characters converted to lowercase: {uppercase_count}")
print("Text after converting to lowercase:\n")

print(text_lower)
print("\n" + "="*50 + "\n")
# Out:
# Number of uppercase characters converted to lowercase: 32
# Text after converting to lowercase:
#
# natural language processing (nlp) is a branch of artificial intelligence.  it helps computers understand and process human language.
#
# in 2026, nlp is used in many applications such as chatbots, machine translation, sentiment analysis, and text summarization!!!
#
# text preprocessing is an important step in nlp.   it includes several operations such as cleaning text, removing punctuation, and removing unnecessary numbers.
#
# for example, a chatbot may process 1000+ customer messages every day. these messages can contain capital letters, numbers like 12345, punctuation marks!!!, and   extra spaces.
#
# the main goal of text preprocessing is to convert raw text into a clean and consistent format. this makes the text easier to analyze and use for further natural language processing tasks.
#
# ...

# %%
# Step 3: Remove punctuation and count different types of punctuations
import string

punctuation_chars = set()
for char in text_lower:
  # 'string.punctuation' is a string that contains -> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
    if char in string.punctuation:
        punctuation_chars.add(char)

punctuation_count = len(punctuation_chars)

text_no_punctuation = ''.join([char for char in text_lower if char not in string.punctuation])

print(f"Number of different types of punctuations removed: {punctuation_count}")
print(f"Punctuation characters removed: {' '.join(sorted(list(punctuation_chars))) if punctuation_chars else 'None'}")
print("Text after removing punctuation:")
print(text_no_punctuation)
print("\n" + "="*50 + "\n")
# Out:
# Number of different types of punctuations removed: 6
# Punctuation characters removed: ! ( ) + , .
# Text after removing punctuation:
# natural language processing nlp is a branch of artificial intelligence  it helps computers understand and process human language
#
# in 2026 nlp is used in many applications such as chatbots machine translation sentiment analysis and text summarization
#
# text preprocessing is an important step in nlp   it includes several operations such as cleaning text removing punctuation and removing unnecessary numbers
#
# for example a chatbot may process 1000 customer messages every day these messages can contain capital letters numbers like 12345 punctuation marks and   extra spaces
#
# the main goal of text preprocessing is to convert raw text into a clean and consistent format this makes the text easier to analyze and use for further natural language processing tasks
#
# ...

# %%
# Step 4: Remove numbers and count numbers

number_count = sum(1 for char in text_no_punctuation if char.isdigit())
text_no_numbers = ''.join([char for char in text_no_punctuation if not char.isdigit()])

print(f"Number of numeric characters removed: {number_count}")
print("Text after removing numbers:")
print(text_no_numbers)
print("\n" + "="*50 + "\n")
# Out:
# Number of numeric characters removed: 13
# Text after removing numbers:
# natural language processing nlp is a branch of artificial intelligence  it helps computers understand and process human language
#
# in  nlp is used in many applications such as chatbots machine translation sentiment analysis and text summarization
#
# text preprocessing is an important step in nlp   it includes several operations such as cleaning text removing punctuation and removing unnecessary numbers
#
# for example a chatbot may process  customer messages every day these messages can contain capital letters numbers like  punctuation marks and   extra spaces
#
# the main goal of text preprocessing is to convert raw text into a clean and consistent format this makes the text easier to analyze and use for further natural language processing tasks
#
# ...

# %%
# Step 5: Remove extra whitespace and count extra whitespace
import re

# Count original whitespace for comparison
original_whitespace_count = sum(1 for char in text_no_numbers if char.isspace())

# Replace multiple spaces with a single space and strip leading/trailing whitespace
text_no_extra_whitespace = re.sub(r'\s+', ' ', text_no_numbers).strip()
# strip(): remove spaces at the beginning or end of the text..
# Count new whitespace
cleaned_whitespace_count = sum(1 for char in text_no_extra_whitespace if char.isspace())

extra_whitespace_removed = original_whitespace_count - cleaned_whitespace_count

print(f"Extra whitespace characters removed: {extra_whitespace_removed}")
print("Text after removing extra whitespace:")
print(text_no_extra_whitespace)
print("\n" + "="*50 + "\n")
# Out:
# Extra whitespace characters removed: 12
# Text after removing extra whitespace:
# natural language processing nlp is a branch of artificial intelligence it helps computers understand and process human language in nlp is used in many applications such as chatbots machine translation sentiment analysis and text summarization text preprocessing is an important step in nlp it includes several operations such as cleaning text removing punctuation and removing unnecessary numbers for example a chatbot may process customer messages every day these messages can contain capital letters numbers like punctuation marks and extra spaces the main goal of text preprocessing is to convert raw text into a clean and consistent format this makes the text easier to analyze and use for further natural language processing tasks
#
# ...

# %%
# Step 6: Display the cleaned text

cleaned_text = text_no_extra_whitespace

print("Final Cleaned Text:")
print(cleaned_text)
print("\n" + "="*50 + "\n")
# Out:
# Final Cleaned Text:
# natural language processing nlp is a branch of artificial intelligence it helps computers understand and process human language in nlp is used in many applications such as chatbots machine translation sentiment analysis and text summarization text preprocessing is an important step in nlp it includes several operations such as cleaning text removing punctuation and removing unnecessary numbers for example a chatbot may process customer messages every day these messages can contain capital letters numbers like punctuation marks and extra spaces the main goal of text preprocessing is to convert raw text into a clean and consistent format this makes the text easier to analyze and use for further natural language processing tasks
#
# ...

# %% [markdown]
# ## Experiment 2.2: Word and Sentence Tokenization
# Write a Python program to perform word tokenization and sentence tokenization on a given text. Display the resulting words and sentences separately. Provide three separate code implementations:
# *   Using NLTK: Natural language Toolkit
# *   Using spaCy
# *   Without using NLTK/spaCy

# %% [markdown]
# ## Stemming and Lemmatization
#
# When working with natural language, understanding the intended meaning behind words is crucial. To achieve this, we often reduce words to their root or base form, a process known as **canonicalization**.
#
# Two primary techniques for canonicalization are:
#
# ### 2.1 Stemming
# *   **Goal**: Generates the base word by removing affixes (prefixes/suffixes).
# *   **Method**: Uses pre-defined rules to drop affixes.
# *   **Outcome**: Might not always result in semantically meaningful base words.
# *   **Performance**: Faster and computationally less expensive than lemmatization.
#
# ### 2.2 Lemmatization
# *   **Goal**: Groups together inflected forms of a word to reach its base form (lemma).
# *   **Method**: Uses vocabulary and morphological analysis.
# *   **Outcome**: Always results in a semantically meaningful base form (lemma).
# *   **Performance**: Slower and computationally more expensive than stemming.

# %% [markdown]
# ### Experiment 2.2 Implementation

# %%
# Step 1: Read the content from the file for Experiment 2.2
import os

file_name_2_2 = '2.2_tokenization_data.txt'

with open(file_name_2_2, 'r') as f:
    tokenization_text = f.read()

print("Text for Tokenization:")
print(tokenization_text)
print("\n" + "="*50 + "\n")
# Out:
# Text for Tokenization:
# Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence. It enables computers to understand human language. NLP is used in many real-world applications, such as chatbots, machine translation, sentiment analysis, and text summarization.
#
# Text tokenization is one of the first steps in NLP. Sentence tokenization divides a paragraph into individual sentences. Word tokenization divides each sentence into individual words and tokens.
#
# For example, a chatbot receives thousands of messages every day. The system processes these messages and identifies useful information. This information can then be used to provide better responses to users.
#
# ...

# %% [markdown]
# #### 2.2.1 Word and Sentence Tokenization using NLTK

# %%
import nltk

# Download punkt
try:
    # tokenizer data package..
    nltk.data.find('tokenizers/punkt')
except LookupError:
    # punkt: pre-trained ml model
    nltk.download('punkt')

# Download punkt_tab required by newer NLTK versions
try:
    nltk.data.find('tokenizers/punkt_tab')
except LookupError:
    nltk.download('punkt_tab')

print("NLTK setup complete.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# NLTK setup complete.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# Word Tokenization
nltk_words = word_tokenize(tokenization_text)
print("NLTK Word Tokens:")
print(nltk_words)

# Sentence Tokenization
nltk_sentences = sent_tokenize(tokenization_text)
print("\nNLTK Sentence Tokens:")
print(nltk_sentences)
print("\n" + "="*50 + "\n")
# Out:
# NLTK Word Tokens:
# ...

# %% [markdown]
# #### 2.2.2 Word and Sentence Tokenization using spaCy

# %%
# Install spaCy if not already installed
try:
    import spacy
except ImportError:
    # !pip install spacy
    import spacy

# Download a spaCy language model (e.g., 'en_core_web_sm')
try:
    spacy.load('en_core_web_sm')
except OSError:
    # !python -m spacy download en_core_web_sm

print("spaCy setup complete.")
# Out:
# spaCy setup complete.

# %%
import spacy

# Load the English model
nlp = spacy.load('en_core_web_sm')

# Process the text with spaCy
doc = nlp(tokenization_text)

# Word Tokenization (spaCy considers tokens as individual words/punctuation)
spacy_words = [token.text for token in doc]
print("spaCy Word Tokens:")
print(spacy_words)

# Sentence Tokenization
spacy_sentences = [sent.text for sent in doc.sents]
print("\nspaCy Sentence Tokens:")
print(spacy_sentences)
print("\n" + "="*50 + "\n")
# Out:
# spaCy Word Tokens:
# ...

# %% [markdown]
# #### 2.2.3 Word and Sentence Tokenization without NLTK/spaCy

# %%
import re

# --- Word Tokenization (basic approach) ---
# Convert to lowercase, then split by spaces and remove non-alphanumeric characters
# This is a very basic approach and might not handle all cases perfectly.
cleaned_text_for_word_token = re.sub(r'[^\w\s]', '', tokenization_text.lower())
custom_words = cleaned_text_for_word_token.split()
print("Custom Word Tokens:")
print(custom_words)

# --- Sentence Tokenization (basic approach) ---
# Split by common sentence-ending punctuation marks followed by a space
custom_sentences = re.split(r'(?<=[.!?])\s+', tokenization_text.strip())
# `?<=` is a **positive lookbehind** in regular expressions, which checks if a
#  pattern exists directly before the current position without including that pattern in the match.
print("\nCustom Sentence Tokens:")
print(custom_sentences)
print("\n" + "="*50 + "\n")
# Out:
# Custom Word Tokens:
# ['natural', 'language', 'processing', 'nlp', 'is', 'a', 'fascinating', 'field', 'of', 'artificial', 'intelligence', 'it', 'enables', 'computers', 'to', 'understand', 'human', 'language', 'nlp', 'is', 'used', 'in', 'many', 'realworld', 'applications', 'such', 'as', 'chatbots', 'machine', 'translation', 'sentiment', 'analysis', 'and', 'text', 'summarization', 'text', 'tokenization', 'is', 'one', 'of', 'the', 'first', 'steps', 'in', 'nlp', 'sentence', 'tokenization', 'divides', 'a', 'paragraph', 'into', 'individual', 'sentences', 'word', 'tokenization', 'divides', 'each', 'sentence', 'into', 'individual', 'words', 'and', 'tokens', 'for', 'example', 'a', 'chatbot', 'receives', 'thousands', 'of', 'messages', 'every', 'day', 'the', 'system', 'processes', 'these', 'messages', 'and', 'identifies', 'useful', 'information', 'this', 'information', 'can', 'then', 'be', 'used', 'to', 'provide', 'better', 'responses', 'to', 'users']
#
# Custom Sentence Tokens:
# ...

# %% [markdown]
# ## Experiment 2.3: Tokenization and Stop Word Removal
# Write a Python program to tokenize a text and remove commonly occurring stop words (e.g., 'is', 'the', 'a', 'an', 'in', 'of', 'and', 'to', etc.). Display the original and filtered tokens. Also, display the list of stop words separately.

# %% [markdown]
# ### Experiment 2.3 Implementation

# %%
# Step 1: Read the content from the file for Experiment 2.3
import os

file_name_2_3 = '2.3_clean_data.txt'

with open(file_name_2_3, 'r') as f:
    stop_word_text = f.read()

print("Text for Tokenization and Stop Word Removal:")
print(stop_word_text)
print("\n" + "="*50 + "\n")
# Out:
# Text for Tokenization and Stop Word Removal:
# Natural Language Processing is an important field of Artificial Intelligence.
# It is used in many applications such as chatbots, machine translation, sentiment analysis, and text summarization.
#
# The main purpose of NLP is to enable computers to understand and process human language.
# A computer can analyze a large amount of text in a short period of time.
# The removal of stop words is one of the common steps in text preprocessing.
#
# Stop words are commonly occurring words such as the, is, a, an, in, of, and, to, for, on, with, from, by, this, that, and it.
# Removing these words can reduce the size of the text and improve the efficiency of some NLP applications.
#
# ...

# %%
# Step 2: Word Tokenization
from nltk.tokenize import word_tokenize

# Ensure NLTK 'punkt' is downloaded (already checked in 2.2.1)

original_tokens = word_tokenize(stop_word_text.lower()) # Tokenize and convert to lowercase for consistency
print("Original Tokens:")
print(original_tokens)
print("\n" + "="*50 + "\n")
# Out:
# Original Tokens:
# ...

# %%
# Step 3: Define and display Stop Words
from nltk.corpus import stopwords

# Download stopwords if not already downloaded
try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

print("List of English Stop Words:")
print(sorted(list(stop_words)))
print("\n" + "="*50 + "\n")
# Out:
# List of English Stop Words:
# ...

# %%
# Step 4: Remove Stop Words from tokens
filtered_tokens = [word for word in original_tokens if word not in stop_words]

print("Filtered Tokens (after removing stop words):")
print(filtered_tokens)
print("\n" + "="*50 + "\n")
# Out:
# Filtered Tokens (after removing stop words):
# ['natural', 'language', 'processing', 'important', 'field', 'artificial', 'intelligence', '.', 'used', 'many', 'applications', 'chatbots', ',', 'machine', 'translation', ',', 'sentiment', 'analysis', ',', 'text', 'summarization', '.', 'main', 'purpose', 'nlp', 'enable', 'computers', 'understand', 'process', 'human', 'language', '.', 'computer', 'analyze', 'large', 'amount', 'text', 'short', 'period', 'time', '.', 'removal', 'stop', 'words', 'one', 'common', 'steps', 'text', 'preprocessing', '.', 'stop', 'words', 'commonly', 'occurring', 'words', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', '.', 'removing', 'words', 'reduce', 'size', 'text', 'improve', 'efficiency', 'nlp', 'applications', '.']
#
# ...
